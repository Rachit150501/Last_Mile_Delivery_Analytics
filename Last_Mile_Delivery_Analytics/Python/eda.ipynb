# %%
print("Jupyter Working")
# Out:
# Jupyter Working

# %%
import pandas as pd

df = pd.read_csv("../Excel/Cleaned_Data.csv")

df.head()
# Out:
#     Order_ID  Order_Date Promised_Delivery_Date Actual_Delivery_Date     City  \
# 0  ORD100000  27-02-2024             01-03-2024           03-03-2024    Surat
# 1  ORD100001  21-04-2024             28-04-2024           30-04-2024    Delhi
# 2  ORD100002  22-05-2024             25-05-2024           29-05-2024  Kolkata
# 3  ORD100003  12-07-2024             15-07-2024           15-07-2024    Delhi
# 4  ORD100004  29-04-2024             02-05-2024           02-05-2024    Delhi
#
#     Zone Warehouse_ID Delivery_Agent_ID      Vendor Product_Category  ...  \
# 0   West    WH_SRT_01          AGT_0008    BlueDart           Beauty  ...
# 1  North    WH_DEL_01          AGT_0109       Ekart      Electronics  ...
# 2   East    WH_KOL_01          AGT_0138       Dunzo      Electronics  ...
# 3  North    WH_DEL_01          AGT_0075  XpressBees      Electronics  ...
# 4  North    WH_DEL_01          AGT_0044   Delhivery            Books  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                5200 non-null   object
#  1   Order_Date              5200 non-null   object
#  2   Promised_Delivery_Date  5200 non-null   object
#  3   Actual_Delivery_Date    5200 non-null   object
#  4   City                    5200 non-null   object
#  5   Zone                    5200 non-null   object
#  6   Warehouse_ID            5200 non-null   object
#  7   Delivery_Agent_ID       5200 non-null   object
#  8   Vendor                  5200 non-null   object
#  9   Product_Category        5200 non-null   object
#  10  Order_Value_INR         5200 non-null   float64
#  11  Payment_Mode            5200 non-null   object
#  12  Promised_Delivery_Days  5200 non-null   int64
#  13  Actual_Delivery_Days    5200 non-null   int64
# ...

# %%
df.head()
# Out:
#     Order_ID  Order_Date Promised_Delivery_Date Actual_Delivery_Date     City  \
# 0  ORD100000  27-02-2024             01-03-2024           03-03-2024    Surat
# 1  ORD100001  21-04-2024             28-04-2024           30-04-2024    Delhi
# 2  ORD100002  22-05-2024             25-05-2024           29-05-2024  Kolkata
# 3  ORD100003  12-07-2024             15-07-2024           15-07-2024    Delhi
# 4  ORD100004  29-04-2024             02-05-2024           02-05-2024    Delhi
#
#     Zone Warehouse_ID Delivery_Agent_ID      Vendor Product_Category  ...  \
# 0   West    WH_SRT_01          AGT_0008    BlueDart           Beauty  ...
# 1  North    WH_DEL_01          AGT_0109       Ekart      Electronics  ...
# 2   East    WH_KOL_01          AGT_0138       Dunzo      Electronics  ...
# 3  North    WH_DEL_01          AGT_0075  XpressBees      Electronics  ...
# 4  North    WH_DEL_01          AGT_0044   Delhivery            Books  ...
#
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                     0
# Order_Date                   0
# Promised_Delivery_Date       0
# Actual_Delivery_Date         0
# City                         0
# Zone                         0
# Warehouse_ID                 0
# Delivery_Agent_ID            0
# Vendor                       0
# Product_Category             0
# Order_Value_INR              0
# Payment_Mode                 0
# Promised_Delivery_Days       0
# Actual_Delivery_Days         0
# Delay_Days                   0
# Delay_Category               0
# Is_Delayed                   0
# Delay_Reason              3197
# SLA_Breached                 0
# Delivery_Attempts            0
# Month                        0
# Quarter                      0
# Is_Festive_Season            0
# Is_Monsoon_Season            0
# dtype: int64

# %%
df.shape
# Out:
# (5200, 24)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Promised_Delivery_Date',
#        'Actual_Delivery_Date', 'City', 'Zone', 'Warehouse_ID',
#        'Delivery_Agent_ID', 'Vendor', 'Product_Category', 'Order_Value_INR',
#        'Payment_Mode', 'Promised_Delivery_Days', 'Actual_Delivery_Days',
#        'Delay_Days', 'Delay_Category', 'Is_Delayed', 'Delay_Reason',
#        'SLA_Breached', 'Delivery_Attempts', 'Month', 'Quarter',
#        'Is_Festive_Season', 'Is_Monsoon_Season'],
#       dtype='object')

# %%
df["City"].value_counts()
# Out:
# City
# Surat        373
# Mumbai       370
# Bhopal       368
# Chennai      357
# Indore       355
# Delhi        352
# Lucknow      352
# Kolkata      350
# Nagpur       349
# Bangalore    340
# Pune         337
# Patna        329
# Ahmedabad    329
# Jaipur       326
# Hyderabad    313
# Name: count, dtype: int64

# %%
df["Vendor"].value_counts()
# Out:
# Vendor
# Ecom Express    681
# Dunzo           669
# Ekart           668
# DTDC            644
# XpressBees      639
# Shadowfax       635
# BlueDart        632
# Delhivery       632
# Name: count, dtype: int64

# %%
df["Delay_Reason"].value_counts()
# Out:
# Delay_Reason
# Traffic Congestion            277
# Warehouse Processing Delay    257
# Weather Conditions            255
# Wrong Address                 248
# Route Optimization Failure    248
# Customer Unavailable          242
# High Order Volume             241
# Vehicle Breakdown             235
# Name: count, dtype: int64
